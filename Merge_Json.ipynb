# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2
import json
from google.colab.patches import cv2_imshow
import pprint
import os
import random
from PIL import Image
import copy
pp = pprint.PrettyPrinter(indent=1)
extra=0

# %%
f_json={'images':[],'annotations':[],'categories': [{'color': '#34d34d',
                 'id': 4,
                 'keypoint_colors': ['#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000',
                                     '#000'],
                 'keypoints': ['top_front_left',
                               'top_front_right',
                               'top_back_left',
                               'top_back_right',
                               'bot_front_left',
                               'bot_front_right',
                               'bot_back_left',
                               'bot_back_right',
                               'nose',
                               'left_eye',
                               'right_eye',
                               'left_ear',
                               'right_ear',
                               'left_shoulder',
                               'right_shoulder',
                               'left_elbow',
                               'right_elbow',
                               'left_wrist',
                               'right_wrist',
                               'left_hip',
                               'right_hip',
                               'left_knee',
                               'right_knee',
                               'left_ankle',
                               'right_ankle'],
                 'metadata': {},
                 'name': 'forklift-person',
                 'skeleton': [[1, 2],
                              [1, 3],
                              [1, 5],
                              [2, 4],
                              [2, 6],
                              [3, 7],
                              [3, 4],
                              [4, 8],
                              [5, 6],
                              [5, 7],
                              [6, 8],
                              [7, 8],
                              [ 9, 10],
                              [ 9, 11],
                              [10, 11],
                              [10, 12],
                              [11, 13],
                              [12, 14],
                              [13, 15],
                              [14, 20],
                              [14, 15],
                              [14, 16],
                              [15, 21],
                              [15, 17],
                              [16, 18],
                              [17, 19],
                              [20, 22],
                              [20, 21],
                              [21, 23],
                              [22, 24],
                              [23, 25]],
                 'supercategory': ''}]}

# %%
f = open('drive/MyDrive/TRTPose/Dataset_Training/person_keypoints_train2017_updated.json')
data1 = json.load(f)
f = open('drive/MyDrive/TRTPose/Dataset_Training/Train_Data_updated_old.json')
data2 = json.load(f)

# %%
print(len(data1['annotations']),len(data1['images']),len(data2['annotations']),len(data2['images']))
# Out:
# 262465 118287 5778 3032

# %%
imid=[]
com=[]
for i in data1['images']:
  imid.append(i['id'])
for j in data2['images']:
  if(j['id'] in imid):
    com.append(j['id'])
    #j['id']=j['id']*50

# %%
print(len(com))
# Out:
# 0

# %%
for ann in data2['annotations']:
  if(ann['image_id'] in com):
    ann['image_id']=ann['image_id']*50

# %%
for ann in data1['annotations']:
  f_json['annotations'].append(ann)
for ann in data2['annotations']:
  f_json['annotations'].append(ann)

# %%
for img in data1['images']:
  f_json['images'].append(img)
for img in data2['images']:
  f_json['images'].append(img)

# %%
print(len(f_json['annotations']),len(f_json['images']),len(data2['annotations'])+len(data1['annotations']),len(data1['images'])+len(data2['images']))
# Out:
# 268243 121319 268243 121319

# %%
with open('drive/MyDrive/TRTPose/Dataset_Training/Train_Data_updated_1.json', "w") as outfile:
    json.dump(f_json, outfile)

# %%
path=os.listdir()

# %%
check=['000000001180.jpg', '6_merged.jpg', '4_merged.jpg', '000000000459.jpg', '8_merged.jpg', '000000000831.jpg', '000000000034.jpg', '9_merged.jpg', '11_merged.jpg', '000000000761.jpg', '2_merged.jpg', '000000000761(1).jpg', '15_merged.jpg', '000000000241.jpg', '000000000089.jpg', '1_merged.jpg', '13_merged.jpg', '7_merged.jpg', '10_merged.jpg']

# %%
f = open('drive/MyDrive/TRTPose/Dataset_Training/Train_Data_updated.json')
data1 = json.load(f)

# %%
imid=[]
for im in data1['images']:
  if(im['file_name'] in check):
    f_json['images'].append(im)
    imid.append(im['id'])

# %%
print(len(imid),len(check))
# Out:
# 18 19

# %%
for ann in data1['annotations']:
  if(ann['image_id'] in imid):
    f_json['annotations'].append(ann)

# %%
print(len(f_json['annotations']))
# Out:
# 51

# %%
ann=[]
for im in data1['annotations']:
  if (not(im['image_id'] in imid)):
    ann.append(im['image_id'])
print(len(ann),len(set(ann)))
# Out:
# 0 0

# %%
ann=[]
for im in data1['images']:
  ann.append(im['file_name'])
print(len(ann),len(set(ann)))
# Out:
# 121319 121319

# %%
for i in natsorted(ann):
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 000000562879.jpg
# 000000562885.jpg
# 000000562895.jpg
# 000000562897.jpg
# 000000562901.jpg
# 000000562904.jpg
# 000000562906.jpg
# 000000562911.jpg
# 000000562916.jpg
# 000000562930.jpg
# 000000562936.jpg
# 000000562937.jpg
# 000000562940.jpg
# 000000562943.jpg
# 000000562960.jpg
# 000000562972.jpg
# 000000562973.jpg
# 000000562989.jpg
# 000000562994.jpg
# 000000562999.jpg
# 000000563009.jpg
# 000000563011.jpg
# 000000563015.jpg
# 000000563024.jpg
# 000000563028.jpg
# 000000563029.jpg
# 000000563031.jpg
# 000000563040.jpg
# 000000563045.jpg
# 000000563046.jpg
# 000000563048.jpg
# 000000563050.jpg
# 000000563053.jpg
# 000000563056.jpg
# 000000563058.jpg
# 000000563061.jpg
# 000000563062.jpg
# 000000563065.jpg
# 000000563067.jpg
# 000000563070.jpg
# 000000563076.jpg
# 000000563083.jpg
# 000000563098.jpg
# 000000563110.jpg
# 000000563122.jpg
# 000000563123.jpg
# 000000563127.jpg
# 000000563129.jpg
# 000000563138.jpg
# ...

# %%
from natsort import natsorted

# %%
a=['a','a']
print(len(a),len(set(a)))
# Out:
# 2 1
